# %%
import os
import numpy as np
import pandas as pd
import bokeh.io
from bokeh.plotting import figure
bokeh.io.output_notebook()

import pili_fluo_utils as pili
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# pili_fluo_utils loaded successfully

# %%
cwd = os.getcwd()
                        
df_pilB = pd.read_csv(os.path.join(cwd, "Data", "pilB_mNG_fliC-", "PolesData_pilB_mNG_fliC-.csv"), sep=',', na_values='*')
df_pilT = pd.read_csv(os.path.join(cwd, "Data", "mNG_pilT_fliC-", "PolesData_mNG_pilT_fliC-.csv"), sep=',', na_values='*')
df_pilU = pd.read_csv(os.path.join(cwd, "Data", "mNG_pilU_fliC-", "PolesData_mNG_pilU_fliC-.csv"), sep=',', na_values='*')
df_pilG = pd.read_csv(os.path.join(cwd, "Data", "mNG_pilG_fliC-", "PolesData_mNG_pilG_fliC-.csv"), sep=',', na_values='*')

# %%
persent_pilB_b, persent_pilB_d, persent_pilB_s, n_b, n_d, n_s, n_B = pili.persentage_difference_biorep(df_pilB,0)
print("PilB")
print("Percent of cells with more pili at bright pole = "+str(persent_pilB_b))
print("Percent of cells with more pili at dim pole = "+str(persent_pilB_d))
print("Percent of cells with same number of pili at both poles = "+str(persent_pilB_s))
print('N cells = '+str(n_B)+',  N more at bright pole = '+str(n_b)+',  N more at dim pole = '+str(n_d)+',  N same at both pole = '+str(n_s)+'\n')

persent_pilT_b, persent_pilT_d, persent_pilT_s, n_b, n_d, n_s, n_T = pili.persentage_difference_biorep(df_pilT,0)
print("PilT")
print("Percent of cells with more pili at bright pole = "+str(persent_pilT_b))
print("Percent of cells with more pili at dim pole = "+str(persent_pilT_d))
print("Percent of cells with same number of pili at both poles = "+str(persent_pilT_s))
print('N cells = '+str(n_T)+',  N more at bright pole = '+str(n_b)+',  N more at dim pole = '+str(n_d)+',  N same at both pole = '+str(n_s)+'\n')

persent_pilU_b, persent_pilU_d, persent_pilU_s, n_b, n_d, n_s, n_U = pili.persentage_difference_biorep(df_pilU,0)
print("PilU")
print("Percent of cells with more pili at bright pole = "+str(persent_pilU_b))
print("Percent of cells with more pili at dim pole = "+str(persent_pilU_d))
print("Percent of cells with same number of pili at both poles = "+str(persent_pilU_s))
print('N cells = '+str(n_U)+',  N more at bright pole = '+str(n_b)+',  N more at dim pole = '+str(n_d)+',  N same at both pole = '+str(n_s)+'\n')

persent_pilG_b, persent_pilG_d, persent_pilG_s, n_b, n_d, n_s, n_G = pili.persentage_difference_biorep(df_pilG,0)
print("PilG")
print("Percent of cells with more pili at bright pole = "+str(persent_pilG_b))
print("Percent of cells with more pili at dim pole = "+str(persent_pilG_d))
print("Percent of cells with same number of pili at both poles = "+str(persent_pilG_s))
print('N cells = '+str(n_G)+',  N more at bright pole = '+str(n_b)+',  N more at dim pole = '+str(n_d)+',  N same at both pole = '+str(n_s)+'\n')

piliDim=np.array([np.mean(persent_pilB_d), np.mean(persent_pilT_d), np.mean(persent_pilU_d), np.mean(persent_pilG_d)])
piliSame=np.array([np.mean(persent_pilB_s), np.mean(persent_pilT_s), np.mean(persent_pilU_s), np.mean(persent_pilG_s)])
piliBright=np.array([np.mean(persent_pilB_b), np.mean(persent_pilT_b), np.mean(persent_pilU_b), np.mean(persent_pilG_b)])
piliDim_std=np.array([np.std(persent_pilB_d), np.std(persent_pilT_d), np.std(persent_pilU_d), np.std(persent_pilG_d)])
piliSame_std=np.array([np.std(persent_pilB_s), np.std(persent_pilT_s), np.std(persent_pilU_s), np.std(persent_pilG_s)])
piliBright_std=np.array([np.std(persent_pilB_b), np.std(persent_pilT_b), np.std(persent_pilU_b), np.std(persent_pilG_b)])
persent_piliBright=[persent_pilB_b, persent_pilT_b, persent_pilU_b, persent_pilG_b]
persent_piliDim=[persent_pilB_d, persent_pilT_d, persent_pilU_d, persent_pilG_d]
persent_piliSame=[persent_pilB_s, persent_pilT_s, persent_pilU_s, persent_pilG_s]
nb_cells=np.array([n_B, n_T, n_U, n_G], dtype=object)

X=["pilB_mNG", "mNG_pilT", "mNG_pilU", "mNG_pilG"]
# Out:
# PilB
# Percent of cells with more pili at bright pole = [66.07142857142857, 62.857142857142854, 75.0, 72.91666666666666, 61.904761904761905, 50.0]
# Percent of cells with more pili at dim pole = [28.57142857142857, 28.57142857142857, 10.0, 18.75, 38.095238095238095, 10.0]
# Percent of cells with same number of pili at both poles = [5.357142857142857, 8.571428571428571, 15.0, 8.333333333333332, 0.0, 40.0]
# N cells = [56, 35, 20, 48, 21, 20],  N more at bright pole = [37, 22, 15, 35, 13, 10],  N more at dim pole = [16, 10, 2, 9, 8, 2],  N same at both pole = [3, 3, 3, 4, 0, 8]
#
# PilT
# Percent of cells with more pili at bright pole = [46.93877551020408, 54.0, 44.11764705882353, 31.03448275862069, 31.25]
# Percent of cells with more pili at dim pole = [48.97959183673469, 36.0, 38.23529411764706, 37.93103448275862, 43.75]
# Percent of cells with same number of pili at both poles = [4.081632653061225, 10.0, 17.647058823529413, 31.03448275862069, 25.0]
# N cells = [49, 50, 34, 29, 32],  N more at bright pole = [23, 27, 15, 9, 10],  N more at dim pole = [24, 18, 13, 11, 14],  N same at both pole = [2, 5, 6, 9, 8]
#
# PilU
# Percent of cells with more pili at bright pole = [52.63157894736842, 51.85185185185185, 43.75, 47.368421052631575, 42.5]
# Percent of cells with more pili at dim pole = [40.35087719298245, 27.77777777777778, 37.5, 28.947368421052634, 45.0]
# Percent of cells with same number of pili at both poles = [7.017543859649122, 20.37037037037037, 18.75, 23.684210526315788, 12.5]
# N cells = [57, 54, 32, 38, 40],  N more at bright pole = [30, 28, 14, 18, 17],  N more at dim pole = [23, 15, 12, 11, 18],  N same at both pole = [4, 11, 6, 9, 5]
#
# PilG
# Percent of cells with more pili at bright pole = [71.42857142857143, 76.19047619047619, 55.55555555555556, 70.83333333333334, 75.0, 57.14285714285714]
# Percent of cells with more pili at dim pole = [21.428571428571427, 14.285714285714285, 25.925925925925924, 25.0, 16.666666666666664, 14.285714285714285]
# Percent of cells with same number of pili at both poles = [7.142857142857142, 9.523809523809524, 18.51851851851852, 4.166666666666666, 8.333333333333332, 28.57142857142857]
# N cells = [28, 21, 27, 24, 12, 14],  N more at bright pole = [20, 16, 15, 17, 9, 8],  N more at dim pole = [6, 3, 7, 6, 2, 2],  N same at both pole = [2, 2, 5, 1, 1, 4]

# %%
p = figure(x_range=(0, 100), y_range=np.array(np.flip(X[0:3]),dtype=object), plot_height=300, plot_width=500, x_axis_label = 'Fraction of cells (%)', title="Fig 3C: Fraction of cells with more T4P at bright or dim pole")
colors=np.array(np.flip(["#26a9e0", "#37b34a", "#90278e"]),dtype=object)
pili.plot_data(np.array(np.flip(persent_piliBright[0:3]),dtype=object), p, 0.6, colors, False, 0.01, 'Bright')
pili.plot_mean(np.array(np.flip(piliBright[0:3]),dtype=object), p, 0.6)
pili.plot_data(np.array(np.flip(persent_piliDim[0:3]),dtype=object), p, 0.3, colors, True, 0.01, 'Dim')
pili.plot_mean(np.array(np.flip(piliDim[0:3]),dtype=object), p, 0.3)

p.legend.location = "top_left"
p.legend.orientation = "horizontal"
p.y_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None

p.output_backend = 'svg'
bokeh.io.show(p)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
#   <div class="bk-root" id="4f591bdd-c0f2-4d7b-ac22-08a392187152" data-root-id="1002"></div>

# %%
p = figure(x_range=(0, 100), y_range=np.flip([X[3], X[0]]), plot_height=250, plot_width=500, x_axis_label = 'Fraction of cells (%)', title="Fig 6F: Fraction of cells with more T4P at bright or dim pole")
colors=np.flip(["#00a69c", "#808184"])
pili.plot_data(np.flip([persent_piliBright[3],persent_piliBright[0]]), p, 0.6, colors, False, 0.01, 'Bright')
pili.plot_mean(np.flip([piliBright[3],piliBright[0]]), p, 0.6)
pili.plot_data(np.flip([persent_piliDim[3], persent_piliDim[0]]), p, 0.3, colors, True, 0.01, 'Dim')
pili.plot_mean(np.flip([piliDim[3], piliDim[0]]), p, 0.3)

p.y_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

p.output_backend = 'svg'
bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="be6d3b36-c104-4f29-9ca7-45d1b4dde2ac" data-root-id="3063"></div>
